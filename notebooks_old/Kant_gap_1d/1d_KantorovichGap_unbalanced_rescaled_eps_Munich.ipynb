# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
#import jax
#jax.config.update('jax_platform_name', 'cpu')

# %%
from entot.data.data import create_gaussians, create_gaussian_split
from entot.plotting.plots import plot_1D, plot_1D_unbalanced
from entot.models.models import NoiseOutsourcingModel, KantorovichGapModel
from entot.models.utils import MixtureNormalSampler, Simple_MLP
import matplotlib.pyplot as plt
import numpy as np
import jax
import jax.numpy as jnp
# Out:
# 2023-06-14 16:45:22.733240: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
sampler_source = MixtureNormalSampler([-1,0.0,2.0], 1,  0.1, batch_size=512)
sampler_target = MixtureNormalSampler([0.0], 1,  0.2, batch_size=512)

# %%
source = sampler_source(jax.random.PRNGKey(0))
target = sampler_target(jax.random.PRNGKey(0))

# %%
from ott.solvers.linear import sinkhorn
from ott.problems.linear import linear_problem
from ott.geometry.pointcloud import PointCloud

# %%
source=source.sort(axis=0)
target =target.sort(axis=0)

# %%
geom = PointCloud(source, target, epsilon=1e-3)

# %%
sinkhorn_output_unbalanced = sinkhorn.Sinkhorn()(
            linear_problem.LinearProblem(geom, tau_a=0.999, tau_b=0.999)
        )

sinkhorn_output_balanced = sinkhorn.Sinkhorn()(
        linear_problem.LinearProblem(geom, tau_a=1.0, tau_b=1.0)
    )

# %%
fig, axes = plt.subplots(1,2, figsize=(12, 8), dpi=150)
axes[0].imshow(sinkhorn_output_balanced.matrix)
axes[1].imshow(sinkhorn_output_unbalanced.matrix)

# %%
import pandas as pd
from entot.models.utils import _concatenate
pi_star_inds = jax.random.categorical(jax.random.PRNGKey(0), logits=jnp.log(sinkhorn_output_unbalanced.matrix.flatten()), shape=(len(source),))
inds_source = pi_star_inds // len(target)
inds_target = pi_star_inds % len(target)
data = _concatenate(source[inds_source], target[inds_target])
gt_unbalanced = pd.DataFrame(data = data, columns=["source", "target"])

pi_star_inds = jax.random.categorical(jax.random.PRNGKey(0), logits=jnp.log(sinkhorn_output_balanced.matrix.flatten()), shape=(len(source),))
inds_source = pi_star_inds // len(target)
inds_target = pi_star_inds % len(target)
data = _concatenate(source[inds_source], target[inds_target])
gt_balanced = pd.DataFrame(data = data, columns=["source", "target"])

# %%
import seaborn as sns

fig, axes = plt.subplots(1,2, figsize=(12, 8), dpi=150)
sns.kdeplot(gt_balanced, x="source", y="target", ax=axes[0], bw_adjust=0.5)
sns.kdeplot(gt_unbalanced, x="source", y="target", ax=axes[1], bw_adjust=0.5)
# Out:
# <Axes: xlabel='source', ylabel='target'>

# %%
from entot.models.utils import MLP
import flax.linen as nn

mlp_eta = Simple_MLP([64, 64, 64], nn.selu, 1, nn.relu)
mlp_xi = Simple_MLP([64, 64, 64], nn.selu, 1, nn.relu)
unbalanced_kwargs= {"tau_a": 0.995, "tau_b": 0.999, "epsilon": 1e-3, "model": 1}

# %%
callback_kwargs={"00_xlim": (-3,3), "01_xlim": (-3,3), "02_xlim": (-3,3), "bw_adjust": 0.4}

# %%
kg = KantorovichGapModel(epsilon=1e-3, input_dim=[1], callback=plot_1D_unbalanced, k_noise_per_x=1, iterations=2000, callback_iters=100, mlp_eta=mlp_eta, mlp_xi=mlp_xi, unbalanced_kwargs=unbalanced_kwargs, callback_kwargs=callback_kwargs)

# %%
kg(sampler_source, sampler_target)
# Out:
#  30%|██▉       | 590/2000 [07:11<17:12,  1.37it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File <__array_function__ internals>:180, in result_type(*args, **kwargs)
#
# TypeError: Cannot interpret 'Traced<ConcreteArray([[-1.5614909  -1.2148994  -0.09205773 -2.014913    1.7163202   0.89460534
#    0.3378212  -0.149761   -0.2533738  -0.18714106  0.8330533  -0.20208107
#    0.912578    0.9753868  -0.20390086 -0.5385833  -0.42912278 -0.11766744
#   -1.2804065  -0.09059517 -0.13756417  2.0525477  -1.9288411   1.2591828
#   -0.10365379 -1.2276454  -0.5563176  -0.04488302 -0.07011045  0.84254354
#   -0.4717127  -0.41807008  1.7623887   1.1108367   0.76553226  0.42590597
#   -1.9895725   0.7633384   0.61881006 -0.6237149  -0.19933975  0.2460463
#   -0.52062595  0.9753719   1.3607252  -0.5995032  -0.31762534 -0.36728597
#    0.42963573  0.34170604 -2.2140336   0.34711498 -0.14550884 -0.02736657
#   -0.53093785  1.3698468   1.8660532  -0.63951826  0.5590244  -2.0279815
#    1.5581967   0.61649346  0.40835592  0.9338461 ]], dtype=float32)>with<JVPTrace(level=2/0)> with
#   primal = Array([[-1.5614909 , -1.2148994 , -0.09205773, -2.014913  ,  1.7163202 ,
#          0.89460534,  0.3378212 , -0.149761  , -0.2533738 , -0.18714106,
#          0.8330533 , -0.20208107,  0.912578  ,  0.9753868 , -0.20390086,
#         -0.5385833 , -0.42912278, -0.11766744, -1.2804065 , -0.09059517,
#         -0.13756417,  2.0525477 , -1.9288411 ,  1.2591828 , -0.10365379,
#         -1.2276454 , -0.5563176 , -0.04488302, -0.07011045,  0.84254354,
#         -0.4717127 , -0.41807008,  1.7623887 ,  1.1108367 ,  0.76553226,
#          0.42590597, -1.9895725 ,  0.7633384 ,  0.61881006, -0.6237149 ,
#         -0.19933975,  0.2460463 , -0.52062595,  0.9753719 ,  1.3607252 ,
#         -0.5995032 , -0.31762534, -0.36728597,  0.42963573,  0.34170604,
#         -2.2140336 ,  0.34711498, -0.14550884, -0.02736657, -0.53093785,
#          1.3698468 ,  1.8660532 , -0.63951826,  0.5590244 , -2.0279815 ,
#          1.5581967 ,  0.61649346,  0.40835592,  0.9338461 ]],      dtype=float32)
#   tangent = Traced<ShapedArray(float32[1,64])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float32[1,64]), None)
#     recipe = LambdaBinding()' as a data type
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 kg(sampler_source, sampler_target)
#
# File ~/git_repos/entot/entot/models/models.py:663, in KantorovichGapModel.__call__(self, x, y)
#     661 batch["source"] = jnp.concatenate((source_batch, latent_batch), axis=-1)
#     662 batch["target"] = self.y_loader(rng_y)
# --> 663 self.state_neural_net, self.state_eta, self.state_xi, metrics, t_xz, sinkhorn_output, sinkhorn_output_unbalanced, eta_predictions, xi_predictions = self.step_fn(self.state_neural_net, self.state_eta, self.state_xi, batch, self.unbalanced_kwargs)
#     664 for key, value in metrics.items():
#     665     self.metrics[key].append(value)
#
# File ~/git_repos/entot/entot/models/models.py:744, in KantorovichGapModel._get_step_fn.<locals>.step_fn(state_neural_net, state_eta, state_xi, train_batch, unbalanced_kwargs)
#     742 if state_eta is not None:
#     743     grad_a_fn = jax.value_and_grad(loss_a_fn, argnums=0, has_aux=True)
# --> 744     (loss_a, eta_predictions), grads_eta = grad_a_fn(state_eta.params, state_eta.apply_fn, train_batch["source"][..., :-self.noise_dim], sinkhorn_output_unbalanced.matrix.sum(axis=1) * len(train_batch["source"]))
#     745     new_state_eta = state_eta.apply_gradients(grads=grads_eta)
#     746     metrics["loss_eta"] = loss_a
#
#     [... skipping hidden 8 frame]
#
# File ~/git_repos/entot/entot/models/models.py:717, in KantorovichGapModel._get_step_fn.<locals>.loss_a_fn(params_eta, apply_fn_eta, x, a)
#     716 def loss_a_fn(params_eta: Optional[jnp.ndarray], apply_fn_eta: Optional[Callable], x: jnp.ndarray, a: jnp.ndarray) -> float:
# --> 717     eta_predictions = apply_fn_eta({"params": params_eta}, x)
#     718     return optax.l2_loss(eta_predictions[:,0], a).sum(), eta_predictions
#
#     [... skipping hidden 6 frame]
#
# File ~/git_repos/entot/entot/models/utils.py:129, in Simple_MLP.__call__(self, x)
#     127 def __call__(self, x:jnp.ndarray):
#     128     for i in range(len(self.dim_hidden)):
# --> 129         x = self.act_fn(self.ws[i](x))
#     130     return self.final_act_fn(self.ws[-1](x))
#
#     [... skipping hidden 2 frame]
#
# File ~/mambaforge/envs/ott/lib/python3.10/site-packages/flax/linen/linear.py:205, in Dense.__call__(self, inputs)
#     203 else:
#     204   bias = None
# --> 205 inputs, kernel, bias = promote_dtype(inputs, kernel, bias, dtype=self.dtype)
#     206 y = self.dot_general(
#     207     inputs,
#     208     kernel,
#     209     (((inputs.ndim - 1,), (0,)), ((), ())),
#     210     precision=self.precision,
#     211 )
#     212 if bias is not None:
#
# File ~/mambaforge/envs/ott/lib/python3.10/site-packages/flax/linen/dtypes.py:96, in promote_dtype(dtype, inexact, *args)
#      72 def promote_dtype(*args, dtype=None, inexact=True) -> List[Array]:
#      73   """"Promotes input arguments to a specified or inferred dtype.
#      74
#      75   All args are cast to the same dtype. See ``canonicalize_dtype`` for how
#    (...)
#      94     The arguments cast to arrays of the same dtype.
#      95   """
# ---> 96   dtype = canonicalize_dtype(*args, dtype=dtype, inexact=inexact)
#      97   return [jnp.asarray(x, dtype) if x is not None else None
#      98           for x in args]
#
# File ~/mambaforge/envs/ott/lib/python3.10/site-packages/flax/linen/dtypes.py:63, in canonicalize_dtype(dtype, inexact, *args)
#      43 """Canonicalize an optional dtype to the definitive dtype.
#      44
#      45 If the ``dtype`` is None this function will infer the dtype. If it is not
#    (...)
#      60   The dtype that *args should be cast to.
#      61 """
#      62 if dtype is None:
# ---> 63   args_filtered = [jnp.asarray(x) for x in args if x is not None]
#      64   dtype = jnp.result_type(*args_filtered)
#      65   if inexact and not jnp.issubdtype(dtype, jnp.inexact):
#
# File ~/mambaforge/envs/ott/lib/python3.10/site-packages/flax/linen/dtypes.py:63, in <listcomp>(.0)
#      43 """Canonicalize an optional dtype to the definitive dtype.
#      44
#      45 If the ``dtype`` is None this function will infer the dtype. If it is not
#    (...)
#      60   The dtype that *args should be cast to.
#      61 """
#      62 if dtype is None:
# ---> 63   args_filtered = [jnp.asarray(x) for x in args if x is not None]
#      64   dtype = jnp.result_type(*args_filtered)
#      65   if inexact and not jnp.issubdtype(dtype, jnp.inexact):
#
# File ~/mambaforge/envs/ott/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:2042, in asarray(a, dtype, order)
#    2040 if dtype is not None:
#    2041   dtype = dtypes.canonicalize_dtype(dtype, allow_opaque_dtype=True)
# -> 2042 return array(a, dtype=dtype, copy=False, order=order)
#
# File ~/mambaforge/envs/ott/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:2022, in array(object, dtype, copy, order, ndmin)
#    2018     return array(np.asarray(view), dtype, copy, ndmin=ndmin)
#    2020   raise TypeError(f"Unexpected input type for array: {type(object)}")
# -> 2022 out_array: Array = lax_internal._convert_element_type(out, dtype, weak_type=weak_type)
#    2023 if ndmin > ndim(out_array):
#    2024   out_array = lax.expand_dims(out_array, range(ndmin - ndim(out_array)))
#
#     [... skipping hidden 1 frame]
#
# File ~/mambaforge/envs/ott/lib/python3.10/site-packages/jax/_src/dtypes.py:459, in dtype(x, canonicalize)
#     457     dt = np.result_type(x)
#     458   except TypeError as err:
# --> 459     raise TypeError(f"Cannot determine dtype of {x}") from err
#     460 if dt not in _jax_dtype_set and not core.is_opaque_dtype(dt):
#     461   raise TypeError(f"Value '{x}' with dtype {dt} is not a valid JAX array "
#     462                   "type. Only arrays of numeric types are supported by JAX.")
#
# TypeError: Cannot determine dtype of Traced<ConcreteArray([[-1.5614909  -1.2148994  -0.09205773 -2.014913    1.7163202   0.89460534
#    0.3378212  -0.149761   -0.2533738  -0.18714106  0.8330533  -0.20208107
#    0.912578    0.9753868  -0.20390086 -0.5385833  -0.42912278 -0.11766744
#   -1.2804065  -0.09059517 -0.13756417  2.0525477  -1.9288411   1.2591828
#   -0.10365379 -1.2276454  -0.5563176  -0.04488302 -0.07011045  0.84254354
#   -0.4717127  -0.41807008  1.7623887   1.1108367   0.76553226  0.42590597
#   -1.9895725   0.7633384   0.61881006 -0.6237149  -0.19933975  0.2460463
#   -0.52062595  0.9753719   1.3607252  -0.5995032  -0.31762534 -0.36728597
#    0.42963573  0.34170604 -2.2140336   0.34711498 -0.14550884 -0.02736657
#   -0.53093785  1.3698468   1.8660532  -0.63951826  0.5590244  -2.0279815
#    1.5581967   0.61649346  0.40835592  0.9338461 ]], dtype=float32)>with<JVPTrace(level=2/0)> with
#   primal = Array([[-1.5614909 , -1.2148994 , -0.09205773, -2.014913  ,  1.7163202 ,
#          0.89460534,  0.3378212 , -0.149761  , -0.2533738 , -0.18714106,
#          0.8330533 , -0.20208107,  0.912578  ,  0.9753868 , -0.20390086,
#         -0.5385833 , -0.42912278, -0.11766744, -1.2804065 , -0.09059517,
#         -0.13756417,  2.0525477 , -1.9288411 ,  1.2591828 , -0.10365379,
#         -1.2276454 , -0.5563176 , -0.04488302, -0.07011045,  0.84254354,
#         -0.4717127 , -0.41807008,  1.7623887 ,  1.1108367 ,  0.76553226,
#          0.42590597, -1.9895725 ,  0.7633384 ,  0.61881006, -0.6237149 ,
#         -0.19933975,  0.2460463 , -0.52062595,  0.9753719 ,  1.3607252 ,
#         -0.5995032 , -0.31762534, -0.36728597,  0.42963573,  0.34170604,
#         -2.2140336 ,  0.34711498, -0.14550884, -0.02736657, -0.53093785,
#          1.3698468 ,  1.8660532 , -0.63951826,  0.5590244 , -2.0279815 ,
#          1.5581967 ,  0.61649346,  0.40835592,  0.9338461 ]],      dtype=float32)
#   tangent = Traced<ShapedArray(float32[1,64])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float32[1,64]), None)
#     recipe = LambdaBinding()

# %%
plt.plot(np.arange(len(kg.metrics["kant_gap"])), kg.metrics["kant_gap"])

# %%
plt.plot(np.arange(len(kg.metrics["fitting_loss"])), kg.metrics["fitting_loss"])

# %%
plt.plot(np.arange(len(kg.metrics["fitting_loss"])), kg.metrics["loss_eta"])

# %%
plt.plot(np.arange(len(kg.metrics["fitting_loss"])), kg.metrics["loss_xi"])

# %%
x = jnp.linspace(-2, 2, num=1000)[:, None]
res = kg.state_eta.apply_fn({"params": kg.state_eta.params}, x)
plt.scatter(x, res)

# %%
x = jnp.linspace(-5, 10, num=1000)[:, None]
res = kg.state_xi.apply_fn({"params": kg.state_xi.params}, x)
plt.scatter(x, res)
