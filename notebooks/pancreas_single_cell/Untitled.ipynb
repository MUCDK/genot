# %%
import pandas as pd
import seaborn as sns

# %%
df_genot = pd.read_csv("pancreas_unbalanced_95_genot.csv")
df_discrete = pd.read_csv("pancreas_unbalanced_95_discrete.csv")

# %%
df_genot["left_rescaling"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_genot["model"] = "UGENOT-K"
df_genot["left_reweighting"] = df_genot["reweighting_0"]
df_discrete["model"] = "discrete UK"

# %%
df_discrete
# Out:
#                       index   day  n_counts  log_counts  n_genes   mt_frac  \
# 0      GGAAAGCTCTTCTGGC-1-2  14.5   29834.0   10.303404     5182  0.022458
# 1      TTTGGTTAGCTGGAAC-1-2  14.5   12119.0    9.402530     3418  0.023104
# 2      GCACTCTTCACGATGT-1-2  14.5   13043.0    9.476007     4146  0.027908
# 3      TCAACGATCTCCTATA-1-2  14.5   10108.0    9.221083     3364  0.021963
# 4      GCGGGTTGTGTAATGA-1-2  14.5   18686.0    9.835530     4179  0.024724
# ...                     ...   ...       ...         ...      ...       ...
# 12297  AGCGTATTCTATCCCG-1-2  15.5   16573.0    9.715530     3654  0.019550
# 12298  CTCGTACGTGCACTTA-1-2  15.5    6593.0    8.793764     2525  0.025785
# 12299  CATATGGGTGCAGACA-1-2  15.5   24296.0   10.098067     5330  0.029141
# 12300  AAACGGGTCGCATGGC-1-3  15.5    6921.0    8.842316     2776  0.024129
# 12301  GAACCTAGTAAGTTCC-1-2  15.5   10289.0    9.238831     3354  0.028963
#
#       proliferation  G2M_score   S_score clusters_fig3_final  \
# ...
